# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

# %matplotlib inline

# %%
df = pd.read_csv("training_set.csv")
train = df.drop(['ARR_DELAY'], axis = 1)
y = df.ARR_DELAY
df.head()
# Out:
#    UID  DAY_OF_WEEK  CRS_DEP_TIME  TAXI_OUT  TAXI_IN  ACTUAL_ELAPSED_TIME  \
# 0    0            2          1020        11        8                  373
# 1    1            6          1220        13        9                  183
# 2    2            6           945        48        6                  355
# 3    3            1          1437        17        8                  136
# 4    4            1           830        37        7                  114
#
#   DISTANCE  DISTANCE_GROUP  AIRLINE_ID     FL_DATE    ...     FL_NUM  \
# 0    2,701              11       19930  2017-01-03    ...        879
# 1    1,171               5       19805  2017-01-28    ...       2491
# 2    2,552              11       19930  2017-01-21    ...        172
# 3      967               4       19977  2017-01-23    ...       2030
# 4      534               3       19393  2017-01-02    ...       3812
#
#    UNIQUE_CARRIER  ORIGIN   ORIGIN_CITY_NAME ORIGIN_STATE_ABR DEST  \
# 0              AS     SEA        Seattle, WA               WA  LIH
# 1              AA     SAN      San Diego, CA               CA  DFW
# 2              AS     ANC      Anchorage, AK               AK  PHX
# 3              UA     SFO  San Francisco, CA               CA  DEN
# 4              WN     ATL        Atlanta, GA               GA  IAD
#
#           DEST_CITY_NAME DEST_STATE_ABR FIRST_DEP_TIME ARR_DELAY
# 0              Lihue, HI             HI            NaN       -11
# 1  Dallas/Fort Worth, TX             TX            NaN         1
# 2            Phoenix, AZ             AZ            NaN        18
# 3             Denver, CO             CO            NaN         0
# 4         Washington, DC             VA            NaN       197
#
# [5 rows x 22 columns]

# %% [markdown]
# # Data Cleaning

# %%
from sklearn.preprocessing import LabelEncoder  

LE = LabelEncoder()
train['CARRIER'] = le.fit_transform(train['UNIQUE_CARRIER'])
train['ORIG_STATE'] = le.fit_transform(train['ORIGIN_STATE_ABR'])

for i in range(len(train)):
    #print i
    train.loc[i, 'DISTANCE'] = train.loc[i, 'DISTANCE'].replace(',','')
    train.loc[i, 'DISTANCE'] = int(train.loc[i, 'DISTANCE'])
    
    date = train.loc[i, 'FL_DATE']
    train.loc[i, 'FL_DATE'] = datetime.datetime.strptime(date, '%Y-%m-%d')
    
    train.loc[i, 'DAY'] = train.loc[i, 'FL_DATE'].day
    train.loc[i, 'MONTH'] = train.loc[i, 'FL_DATE'].month
    
    if type( train.loc[i,'FIRST_DEP_TIME'] ) == float:
        train.loc[i, 'FIRST_DEP_TIME'] = np.nan
    else:
        train.loc[i, 'FIRST_DEP_TIME'] = train.loc[i, 'FIRST_DEP_TIME'].replace(',','')
        train.loc[i, 'FIRST_DEP_TIME'] = int(train.loc[i, 'FIRST_DEP_TIME'])

# %%
train
# Out:
#        UID  DAY_OF_WEEK  CRS_DEP_TIME  TAXI_OUT  TAXI_IN  ACTUAL_ELAPSED_TIME  \
# 0        0            2          1020        11        8                  373
# 1        1            6          1220        13        9                  183
# 2        2            6           945        48        6                  355
# 3        3            1          1437        17        8                  136
# 4        4            1           830        37        7                  114
# 5        5            7          1735        28        5                  151
# 6        6            4          1240        11        6                   46
# 7        7            1           710        10        4                   75
# 8        9            4           825        22        4                  167
# 9       10            7          1632        43        6                  162
# 10      11            7          1131        22        7                  162
# 11      12            5          1030        14       12                  167
# 12      13            5           519        16        5                   40
# 13      14            1           905        17        7                   62
# 14      16            7           750        12       41                  241
# 15      17            6          1747         5        4                   35
# 16      18            2           700        21        3                  371
# 17      19            2          1100        16       15                   81
# 18      20            2          1604        13        6                   66
# 19      21            1           755        12        5                  110
# 20      22            1          1950        23       33                  108
# 21      25            1          1425        10        5                  136
# 22      26            4          1935        14       10                   89
# 23      27            2          1600        15       10                  363
# 24      30            7          1756        10        3                  132
# 25      31            7          1515        10        5                   68
# 26      32            4          1345        26        7                   81
# 27      34            2          1620        12        7                  186
# 28      35            7          1229        18       15                  199
# 29      36            2          1132        11        3                  103
# ...    ...          ...           ...       ...      ...                  ...
# 4881  5464            5           600        51        7                  256
# 4882  5465            5          1249        12        8                  129
# 4883  5466            3          1253        46       10                  180
# 4884  5467            6           700        18       10                  187
# 4885  5468            1          1020        21        5                   97
# 4886  5469            6           545        18        4                   67
# 4887  5470            3          1305         9        6                   68
# 4888  5471            7           720        10        5                  146
# 4889  5472            6          1735        17        3                   57
# 4890  5473            7          1353        17        5                  270
# 4891  5474            3           745        26       18                   98
# 4892  5475            5           600        14       15                  113
# 4893  5476            1          1045        14        5                  115
# 4894  5477            1          1400        14        3                  105
# 4895  5478            3          1145        18        7                  173
# 4896  5479            7          1220        15        5                  133
# 4897  5480            7          2025        10        3                   65
# 4898  5481            6          1340        11        8                   41
# 4899  5482            6          1425        27        4                   63
# 4900  5483            4          1719        13       10                  100
# 4901  5484            5           956         9        8                  151
# 4902  5486            5           936        11       10                  107
# 4903  5487            5           940        14        2                  152
# 4904  5488            5          1637         8        6                  106
# 4905  5489            3          2146        15        6                   97
# 4906  5490            3          1600         7        3                   85
# 4907  5491            4          1840        28        4                  402
# 4908  5493            5          2045        13        4                  150
# 4909  5494            5          1410        19        8                   85
# 4910  5495            2          1435        12        4                  194
#
#      DISTANCE  DISTANCE_GROUP  AIRLINE_ID              FL_DATE  ...   \
# 0        2701              11       19930  2017-01-03 00:00:00  ...
# 1        1171               5       19805  2017-01-28 00:00:00  ...
# 2        2552              11       19930  2017-01-21 00:00:00  ...
# 3         967               4       19977  2017-01-23 00:00:00  ...
# 4         534               3       19393  2017-01-02 00:00:00  ...
# 5         984               4       20366  2017-01-01 00:00:00  ...
# 6         160               1       20304  2017-01-05 00:00:00  ...
# 7         337               2       20416  2017-01-02 00:00:00  ...
# 8        1250               6       20304  2017-01-05 00:00:00  ...
# 9         852               4       20366  2017-01-15 00:00:00  ...
# 10       1065               5       20416  2017-01-22 00:00:00  ...
# 11        930               4       19790  2017-01-20 00:00:00  ...
# 12         69               1       20304  2017-01-20 00:00:00  ...
# 13        196               1       20366  2017-01-09 00:00:00  ...
# 14       1488               6       19805  2017-01-29 00:00:00  ...
# 15         68               1       20409  2017-01-14 00:00:00  ...
# 16       2603              11       19930  2017-01-31 00:00:00  ...
# 17        235               1       20304  2017-01-17 00:00:00  ...
# 18        236               1       19805  2017-01-10 00:00:00  ...
# 19        623               3       19393  2017-01-09 00:00:00  ...
# 20        337               2       19977  2017-01-30 00:00:00  ...
# 21        834               4       19393  2017-01-23 00:00:00  ...
# 22        440               2       19393  2017-01-19 00:00:00  ...
# 23       2454              10       19977  2017-01-24 00:00:00  ...
# 24        899               4       20409  2017-01-15 00:00:00  ...
# 25        326               2       19393  2017-01-29 00:00:00  ...
# 26        198               1       20304  2017-01-12 00:00:00  ...
# 27        991               4       20436  2017-01-10 00:00:00  ...
# 28       1197               5       20436  2017-01-15 00:00:00  ...
# 29        639               3       19977  2017-01-17 00:00:00  ...
# ...       ...             ...         ...                  ...  ...
# 4881     1589               7       20304  2017-12-08 00:00:00  ...
# 4882      758               4       20436  2017-12-22 00:00:00  ...
# 4883      937               4       19977  2017-12-20 00:00:00  ...
# 4884     1235               5       19805  2017-12-30 00:00:00  ...
# 4885      628               3       19393  2017-12-04 00:00:00  ...
# 4886      261               2       19930  2017-12-02 00:00:00  ...
# 4887      304               2       19393  2017-12-06 00:00:00  ...
# 4888     1023               5       20409  2017-12-10 00:00:00  ...
# 4889      223               1       19790  2017-12-02 00:00:00  ...
# 4890     1590               7       19790  2017-12-24 00:00:00  ...
# 4891      334               2       20304  2017-12-27 00:00:00  ...
# 4892      584               3       20304  2017-12-29 00:00:00  ...
# 4893      628               3       19977  2017-12-18 00:00:00  ...
# 4894      628               3       19393  2017-12-11 00:00:00  ...
# 4895      936               4       19805  2017-12-27 00:00:00  ...
# 4896      852               4       19805  2017-12-03 00:00:00  ...
# 4897      365               2       19393  2017-12-31 00:00:00  ...
# 4898       74               1       20304  2017-12-02 00:00:00  ...
# 4899      125               1       20304  2017-12-30 00:00:00  ...
# 4900      507               3       19805  2017-12-21 00:00:00  ...
# 4901      967               4       19977  2017-12-01 00:00:00  ...
# 4902      550               3       19805  2017-12-29 00:00:00  ...
# 4903     1072               5       19393  2017-12-01 00:00:00  ...
# 4904      680               3       19790  2017-12-29 00:00:00  ...
# 4905      534               3       19790  2017-12-13 00:00:00  ...
# 4906      580               3       19393  2017-12-06 00:00:00  ...
# 4907     2552              11       19930  2017-12-21 00:00:00  ...
# 4908     1217               5       19805  2017-12-08 00:00:00  ...
# 4909      316               2       20366  2017-12-15 00:00:00  ...
# 4910     1167               5       19977  2017-12-26 00:00:00  ...
#
#                     ORIGIN_CITY_NAME  ORIGIN_STATE_ABR  DEST  \
# 0                        Seattle, WA                WA   LIH
# 1                      San Diego, CA                CA   DFW
# 2                      Anchorage, AK                AK   PHX
# 3                  San Francisco, CA                CA   DEN
# 4                        Atlanta, GA                GA   IAD
# 5                        Houston, TX                TX   MKE
# 6                           Yuma, AZ                AZ   PHX
# 7                    Los Angeles, CA                CA   OAK
# 8                 Salt Lake City, UT                UT   ORD
# 9              Dallas/Fort Worth, TX                TX   MSP
# 10               Fort Lauderdale, FL                FL   EWR
# 11                   Minneapolis, MN                MN   CLT
# 12                        Alpena, MI                MI   PLN
# 13                       Chicago, IL                IL   CID
# 14                  Indianapolis, IN                IN   PHX
# 15              Charlotte Amalie, VI                VI   SJU
# 16                      Portland, OR                OR   HNL
# 17                       Detroit, MI                MI   ORD
# 18                     Las Vegas, NV                NV   LAX
# 19                     Nashville, TN                TN   DAL
# 20                 San Francisco, CA                CA   LAX
# 21                       Orlando, FL                FL   PIT
# 22                     St. Louis, MO                MO   DTW
# 23                        Newark, NJ                NJ   LAX
# 24               Fort Lauderdale, FL                FL   DCA
# 25                       Burbank, CA                CA   SFO
# 26                        Alpena, MI                MI   DTW
# 27                        Denver, CO                CO   PDX
# 28                         Miami, FL                FL   ORD
# 29                        Denver, CO                CO   TUS
# ...                              ...               ...   ...
# 4881                 Minneapolis, MN                MN   SFO
# 4882                  Washington, DC                VA   MCO
# 4883                     Orlando, FL                FL   EWR
# 4884                 Los Angeles, CA                CA   DFW
# 4885                   San Diego, CA                CA   ABQ
# 4886                   Fairbanks, AK                AK   ANC
# 4887                   San Diego, CA                CA   PHX
# 4888  West Palm Beach/Palm Beach, FL                FL   EWR
# 4889                     Atlanta, GA                GA   TLH
# 4890                     Atlanta, GA                GA   SLC
# 4891                 Minneapolis, MN                MN   ORD
# 4892                    San Jose, CA                CA   SLC
# 4893                  Charleston, SC                SC   EWR
# 4894                   Las Vegas, NV                NV   DEN
# 4895                   Charlotte, NC                NC   DFW
# 4896           Dallas/Fort Worth, TX                TX   MSP
# 4897                   Las Vegas, NV                NV   TUS
# 4898                     Lansing, MI                MI   DTW
# 4899                      Denver, CO                CO   ASE
# 4900                       Tampa, FL                FL   CLT
# 4901                      Denver, CO                CO   SFO
# 4902                   St. Louis, MO                MO   DFW
# 4903                     Orlando, FL                FL   PVD
# 4904                      Denver, CO                CO   MSP
# 4905                     Atlanta, GA                GA   IAD
# 4906                 Albuquerque, NM                NM   DAL
# 4907                     Phoenix, AZ                AZ   ANC
# 4908           Dallas/Fort Worth, TX                TX   BWI
# 4909    Mission/McAllen/Edinburg, TX                TX   IAH
# 4910                      Newark, NJ                NJ   MSY
#
#                   DEST_CITY_NAME DEST_STATE_ABR FIRST_DEP_TIME CARRIER  \
# 0                      Lihue, HI             HI            NaN       1
# 1          Dallas/Fort Worth, TX             TX            NaN       0
# 2                    Phoenix, AZ             AZ            NaN       1
# 3                     Denver, CO             CO            NaN       9
# 4                 Washington, DC             VA            NaN      11
# 5                  Milwaukee, WI             WI            NaN       4
# 6                    Phoenix, AZ             AZ            NaN       8
# 7                    Oakland, CA             CA            NaN       7
# 8                    Chicago, IL             IL            NaN       8
# 9                Minneapolis, MN             MN            NaN       4
# 10                    Newark, NJ             NJ            NaN       7
# 11                 Charlotte, NC             NC            NaN       3
# 12                  Pellston, MI             MI            NaN       8
# 13    Cedar Rapids/Iowa City, IA             IA            NaN       4
# 14                   Phoenix, AZ             AZ            NaN       0
# 15                  San Juan, PR             PR            NaN       2
# 16                  Honolulu, HI             HI            NaN       1
# 17                   Chicago, IL             IL            NaN       8
# 18               Los Angeles, CA             CA            NaN       0
# 19                    Dallas, TX             TX            752      11
# 20               Los Angeles, CA             CA            NaN       9
# 21                Pittsburgh, PA             PA            NaN      11
# 22                   Detroit, MI             MI            NaN      11
# 23               Los Angeles, CA             CA            NaN       9
# 24                Washington, DC             VA            NaN       2
# 25             San Francisco, CA             CA            NaN      11
# 26                   Detroit, MI             MI            NaN       8
# 27                  Portland, OR             OR            NaN       5
# 28                   Chicago, IL             IL            NaN       5
# 29                    Tucson, AZ             AZ            NaN       9
# ...                          ...            ...            ...     ...
# 4881           San Francisco, CA             CA            NaN       8
# 4882                 Orlando, FL             FL            NaN       5
# 4883                  Newark, NJ             NJ            NaN       9
# 4884       Dallas/Fort Worth, TX             TX            NaN       0
# 4885             Albuquerque, NM             NM            NaN      11
# 4886               Anchorage, AK             AK            NaN       1
# 4887                 Phoenix, AZ             AZ            NaN      11
# 4888                  Newark, NJ             NJ            NaN       2
# 4889             Tallahassee, FL             FL            NaN       3
# 4890          Salt Lake City, UT             UT            NaN       3
# 4891                 Chicago, IL             IL            NaN       8
# 4892          Salt Lake City, UT             UT            NaN       8
# 4893                  Newark, NJ             NJ            NaN       9
# 4894                  Denver, CO             CO            NaN      11
# 4895       Dallas/Fort Worth, TX             TX            NaN       0
# 4896             Minneapolis, MN             MN            NaN       0
# 4897                  Tucson, AZ             AZ            NaN      11
# 4898                 Detroit, MI             MI            NaN       8
# 4899                   Aspen, CO             CO            NaN       8
# 4900               Charlotte, NC             NC            NaN       0
# 4901           San Francisco, CA             CA            NaN       9
# 4902       Dallas/Fort Worth, TX             TX            NaN       0
# 4903              Providence, RI             RI            NaN      11
# 4904             Minneapolis, MN             MN            NaN       3
# 4905              Washington, DC             VA            NaN       3
# 4906                  Dallas, TX             TX            NaN      11
# 4907               Anchorage, AK             AK            NaN       1
# 4908               Baltimore, MD             MD            NaN       0
# 4909                 Houston, TX             TX            NaN       4
# 4910             New Orleans, LA             LA            NaN       9
#
#      ORIG_STATE   DAY MONTH
# 0            47   3.0   1.0
# 1             4  28.0   1.0
# 2             0  21.0   1.0
# 3             4  23.0   1.0
# 4             8   2.0   1.0
# 5            42   1.0   1.0
# 6             3   5.0   1.0
# 7             4   2.0   1.0
# 8            43   5.0   1.0
# 9            42  15.0   1.0
# 10            7  22.0   1.0
# 11           21  20.0   1.0
# 12           20  20.0   1.0
# 13           12   9.0   1.0
# 14           13  29.0   1.0
# 15           45  14.0   1.0
# 16           35  31.0   1.0
# 17           20  17.0   1.0
# 18           31  10.0   1.0
# 19           41   9.0   1.0
# 20            4  30.0   1.0
# 21            7  23.0   1.0
# 22           22  19.0   1.0
# 23           29  24.0   1.0
# 24            7  15.0   1.0
# 25            4  29.0   1.0
# 26           20  12.0   1.0
# 27            5  10.0   1.0
# 28            7  15.0   1.0
# 29            5  17.0   1.0
# ...         ...   ...   ...
# 4881         21   8.0  12.0
# 4882         44  22.0  12.0
# 4883          7  20.0  12.0
# 4884          4  30.0  12.0
# 4885          4   4.0  12.0
# 4886          0   2.0  12.0
# 4887          4   6.0  12.0
# 4888          7  10.0  12.0
# 4889          8   2.0  12.0
# 4890          8  24.0  12.0
# 4891         21  27.0  12.0
# 4892          4  29.0  12.0
# 4893         39  18.0  12.0
# 4894         31  11.0  12.0
# 4895         25  27.0  12.0
# 4896         42   3.0  12.0
# 4897         31  31.0  12.0
# 4898         20   2.0  12.0
# 4899          5  30.0  12.0
# 4900          7  21.0  12.0
# 4901          5   1.0  12.0
# 4902         22  29.0  12.0
# 4903          7   1.0  12.0
# 4904          5  29.0  12.0
# 4905          8  13.0  12.0
# 4906         30   6.0  12.0
# 4907          3  21.0  12.0
# 4908         42   8.0  12.0
# 4909         42  15.0  12.0
# 4910         29  26.0  12.0
#
# [4911 rows x 25 columns]

# %%
# Using Python's Dictionary as Hash-Map to to encode states as integers
# Using the same encoding for Destination State as well (for consistency)
states = {}

for i in range(len(train)):
    key = train.loc[i, 'ORIGIN_STATE_ABR']
    value = train.loc[i, 'ORIG_STATE']
    states[key] = value
    
for i in range(len(train)):
    val = train.loc[i, 'DEST_STATE_ABR']
    train.loc[i, 'DEST_STATE'] = states[val]

# %%
# Dropping the un-cleaned columns (ONLY FOR NOW !!!)
irrel_cols = ['ORIGIN', 'ORIGIN_CITY_NAME', 'DEST', 'DEST_CITY_NAME', 'ORIGIN_STATE_ABR', 'DEST_STATE_ABR', 'UNIQUE_CARRIER']
train = train.drop(irrel_cols, axis=1)

redundant_cols = ['FIRST_DEP_TIME', 'FL_DATE']
train = train.drop(redundant_cols, axis=1)

train.head()
# Out:
#    UID  DAY_OF_WEEK  CRS_DEP_TIME  TAXI_OUT  TAXI_IN  ACTUAL_ELAPSED_TIME  \
# 0    0            2          1020        11        8                  373
# 1    1            6          1220        13        9                  183
# 2    2            6           945        48        6                  355
# 3    3            1          1437        17        8                  136
# 4    4            1           830        37        7                  114
#
#   DISTANCE  DISTANCE_GROUP  AIRLINE_ID  ORIGIN_CITY_MARKET_ID  \
# 0     2701              11       19930                  30559
# 1     1171               5       19805                  33570
# 2     2552              11       19930                  30299
# 3      967               4       19977                  32457
# 4      534               3       19393                  30397
#
#    DEST_CITY_MARKET_ID  FL_NUM  CARRIER  ORIG_STATE   DAY  MONTH  DEST_STATE
# 0                32982     879        1          47   3.0    1.0         9.0
# 1                30194    2491        0           4  28.0    1.0        42.0
# 2                30466     172        1           0  21.0    1.0         3.0
# 3                30325    2030        9           4  23.0    1.0         5.0
# 4                30852    3812       11           8   2.0    1.0        44.0

# %%
plt.plot(y)

# %%
cols = []
for col in train:
    cols.append(col)
    # Printing the data type of last element of every feature
    print col, "\t\t", type(train[col][len(train)-1])
# Out:
# UID 		<type 'numpy.int64'>
# DAY_OF_WEEK 		<type 'numpy.int64'>
# CRS_DEP_TIME 		<type 'numpy.int64'>
# TAXI_OUT 		<type 'numpy.int64'>
# TAXI_IN 		<type 'numpy.int64'>
# ACTUAL_ELAPSED_TIME 		<type 'numpy.int64'>
# DISTANCE 		<type 'int'>
# DISTANCE_GROUP 		<type 'numpy.int64'>
# AIRLINE_ID 		<type 'numpy.int64'>
# ORIGIN_CITY_MARKET_ID 		<type 'numpy.int64'>
# DEST_CITY_MARKET_ID 		<type 'numpy.int64'>
# FL_NUM 		<type 'numpy.int64'>
# CARRIER 		<type 'numpy.int64'>
# ORIG_STATE 		<type 'numpy.int64'>
# DAY 		<type 'numpy.float64'>
# MONTH 		<type 'numpy.float64'>
# DEST_STATE 		<type 'numpy.float64'>

# %%
# Inspecting NaN values in one of the columns

non_nan = [752, 904, 1940, 1813, 654, 1253, 2204, 743, 1103, 1400, 1601,
           1546, 606, 1354, 558, 1749, 1652, 754, 1839, 2341, 1827, 716, 
           1333, 1409, 839, 1002, 608, 1025, 1136]

inspect = []

for i in range(len(train)):
    for j in range(len(non_nan)):
        if train.FIRST_DEP_TIME[i] == non_nan[j]:
            inspect.append([non_nan[j], df.ARR_DELAY[i]])
            
inspect = pd.DataFrame(inspect)

y_axis = inspect[0]
x_axis = inspect[1]

plt.scatter(x_axis, y_axis)
plt.xlabel("FIRST_DEP_TIME")
plt.ylabel("ARR_DELAY")

# %% [markdown]
# # Data Distribution

# %% [markdown]
# ### Box-Plot

# %%
# Distribution of 'Arrival Delay'
plt.figure(figsize = (12, 8))
df.boxplot(column=['ARR_DELAY']) 

count = 0
for i in range(len(df)):
    if df.ARR_DELAY[i] > 50:
        count += 1
        
print "Outliers:", count
# Out:
# Outliers: 350

# %%
ax1 = plt.figure(figsize = (12, 8))
ax1 = train.boxplot(column=['TAXI_OUT', 'TAXI_IN']) 

ax2 = plt.figure(figsize = (12, 8))
ax2 = train.boxplot(column=['FL_NUM', 'CRS_DEP_TIME']) 

ax3 = plt.figure(figsize = (12, 8))
ax3 = train.boxplot(column=['ACTUAL_ELAPSED_TIME'])

# %% [markdown]
# ### Scatter-Plot

# %%
cols = ['DAY_OF_WEEK', 'CRS_DEP_TIME', 'TAXI_OUT', 'TAXI_IN', 'ACTUAL_ELAPSED_TIME', 'DISTANCE_GROUP']
for col in cols:
    print col
    feat = train[col]
    try:
        plt.figure(figsize = (12, 8))
        plt.scatter(feat, y)
        plt.ylabel("Arrival Delay")
        plt.xlabel(col)
        plt.show()
    except ValueError:
        continue
# Out:
# DAY_OF_WEEK
# CRS_DEP_TIME
# TAXI_OUT
# TAXI_IN
# ACTUAL_ELAPSED_TIME
# DISTANCE_GROUP

# %%
for col in train:
    print col
    feat = train[col]
    try:
        plt.scatter(feat, y)
        plt.ylabel("Arrival Delay")
        plt.xlabel(col)
        plt.show()
    except ValueError:
        continue
# Out:
# UID
# DAY_OF_WEEK
# CRS_DEP_TIME
# TAXI_OUT
# TAXI_IN
# ACTUAL_ELAPSED_TIME
# DISTANCE
# DISTANCE_GROUP
# AIRLINE_ID
# FL_DATE
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-739b5ab90fb6> in <module>()
#       3     feat = train[col]
#       4     try:
# ----> 5         plt.scatter(feat, y)
#       6         plt.ylabel("Arrival Delay")
#       7         plt.xlabel(col)
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3432                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3433                          linewidths=linewidths, verts=verts,
# -> 3434                          edgecolors=edgecolors, data=data, **kwargs)
#    3435     finally:
#    3436         ax._hold = washold
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4061                 self.set_ymargin(0.05)
#    4062
# -> 4063         self.add_collection(collection)
#    4064         self.autoscale_view()
#    4065
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in add_collection(self, collection, autolim)
#    1760
#    1761         if autolim:
# -> 1762             self.update_datalim(collection.get_datalim(self.transData))
#    1763
#    1764         collection._remove_method = lambda h: self.collections.remove(h)
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in get_datalim(self, transData)
#     218             transOffset = transOffset.get_affine()
#     219
# --> 220         offsets = np.asanyarray(offsets, np.float_)
#     221         if np.ma.isMaskedArray(offsets):
#     222             offsets = offsets.filled(np.nan)
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.pyc in asanyarray(a, dtype, order)
#     581
#     582     """
# --> 583     return array(a, dtype, copy=False, order=order, subok=True)
#     584
#     585
#
# TypeError: float() argument must be a string or a number
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
#     123     bytes_io = BytesIO()
# --> 124     fig.canvas.print_figure(bytes_io, **kw)
#     125     data = bytes_io.getvalue()
#     126     if fmt == 'svg':
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2208                 bbox_filtered = []
#    2209                 for a in bbox_artists:
# -> 2210                     bbox = a.get_window_extent(renderer)
#    2211                     if a.get_clip_on():
#    2212                         clip_box = a.get_clip_box()
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in get_window_extent(self, renderer)
#     236         # TODO:check to ensure that this does not fail for
#     237         # cases other than scatter plot legend
# --> 238         return self.get_datalim(transforms.IdentityTransform())
#     239
#     240     def _prepare_points(self):
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/matplotlib/collections.pyc in get_datalim(self, transData)
#     218             transOffset = transOffset.get_affine()
#     219
# --> 220         offsets = np.asanyarray(offsets, np.float_)
#     221         if np.ma.isMaskedArray(offsets):
#     222             offsets = offsets.filled(np.nan)
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/numpy/core/numeric.pyc in asanyarray(a, dtype, order)
#     581
#     582     """
# --> 583     return array(a, dtype, copy=False, order=order, subok=True)
#     584
#     585
#
# TypeError: float() argument must be a string or a number

# %%
df.describe()
# Out:
#                UID  DAY_OF_WEEK  CRS_DEP_TIME     TAXI_OUT      TAXI_IN  \
# count  4897.000000  4897.000000   4897.000000  4897.000000  4897.000000
# mean   2761.054319     4.035736   1335.091280    16.565857     7.629569
# std    1582.254661     2.016615    483.863788     9.306015     5.766140
# min       0.000000     1.000000     35.000000     4.000000     1.000000
# 25%    1406.000000     2.000000    917.000000    11.000000     4.000000
# 50%    2771.000000     4.000000   1330.000000    14.000000     6.000000
# 75%    4125.000000     6.000000   1735.000000    19.000000     9.000000
# max    5495.000000     7.000000   2355.000000   123.000000   116.000000
#
#        ACTUAL_ELAPSED_TIME  DISTANCE_GROUP    AIRLINE_ID  \
# count          4897.000000     4897.000000   4897.000000
# mean            142.914233        3.906882  19895.923014
# std              80.412295        2.522511    377.068177
# min              21.000000        1.000000  19393.000000
# 25%              84.000000        2.000000  19790.000000
# 50%             122.000000        3.000000  19805.000000
# 75%             177.000000        5.000000  20304.000000
# max             681.000000       11.000000  21171.000000
#
#        ORIGIN_CITY_MARKET_ID  DEST_CITY_MARKET_ID       FL_NUM    ARR_DELAY
# count            4897.000000          4897.000000  4897.000000  4897.000000
# mean            31702.394936         31758.066163  2126.835205     3.683684
# std              1261.266618          1297.477377  1728.007428    41.856945
# min             30073.000000         30107.000000     1.000000   -59.000000
# 25%             30615.000000         30647.000000   734.000000   -15.000000
# 50%             31453.000000         31454.000000  1700.000000    -6.000000
# 75%             32467.000000         32575.000000  2978.000000     7.000000
# max             35841.000000         35412.000000  7437.000000   965.000000

# %% [markdown]
# # Predictive Modelling

# %% [markdown]
# ### Cross-validation split

# %%
#x = np.array(train.drop(['UID', 'AIRLINE_ID', 'DAY_OF_WEEK', 'DISTANCE_GROUP', 'month'], axis = 1))
x = np.array(train)
y = np.array(y)

#irrelev_feat = ['UID']

# 20% split to test set as it will be used in the very end
x_train, x_test, y_train, y_test = np.array(train_test_split(x, y, train_size = 0.7))

# %% [markdown]
# ## 1. Predicting from the mean

# %%
len(x_test)
# Out:
# 1474

# %%
y_train = np.array(y_train)
mean = y_train.mean()
preds = []

for i in range(len(y_test)):
    preds.append(mean)
    
print "Mean Squared Error:", mse(y_test, preds)
# Out:
# Mean Squared Error: 2024.14339454

# %% [markdown]
# ## 2. Decision Tree

# %% [markdown]
# ### Cross-Validation

# %%
from sklearn.tree import DecisionTreeRegressor

leaves = [1, 2, 3, 5, 7, 10, 15, 20, 30, 40, 50, 70, 100, 200, 500, 1000, 2000, 3000, 4000, 5000, 1000]
for i in leaves:
    print "Leaf:", i
    
    DT_model = DecisionTreeRegressor(min_samples_leaf=i)
    DT_model.fit(x_train, y_train)
    
    preds_train = DT_model.predict(x_train)
    print "\tTraining Error (MSE):", mse(y_train, preds_train)
    
    preds_test = DT_model.predict(x_test)
    print "\tValidation Error (MSE):", mse(y_test, preds_test)
    
    R_squared_train = DT_model.score(x_train, y_train)
    print "\tTraining Error (R^2):", R_squared_train
    
    R_squared_test = DT_model.score(x_test, y_test)
    print "\tValidation Error (R^2):", R_squared_test
# Out:
# Leaf: 1
# 	Training Error (MSE): 0.0
# 	Validation Error (MSE): 1485.46507353
# 	Training Error (R^2): 1.0
# 	Validation Error (R^2): 0.225550422018
# Leaf: 2
# 	Training Error (MSE): 170.329811128
# 	Validation Error (MSE): 1608.78446691
# 	Training Error (R^2): 0.897908833843
# 	Validation Error (R^2): 0.1612576602
# Leaf: 3
# 	Training Error (MSE): 444.350627871
# 	Validation Error (MSE): 1684.04069564
# 	Training Error (R^2): 0.733668032146
# 	Validation Error (R^2): 0.122022705697
# Leaf: 5
# 	Training Error (MSE): 705.646940616
# 	Validation Error (MSE): 1793.93016006
# 	Training Error (R^2): 0.577053960281
# 	Validation Error (R^2): 0.0647316586932
# Leaf: 7
# 	Training Error (MSE): 826.483687705
# 	Validation Error (MSE): 1666.4330103
# 	Training Error (R^2): 0.504627622559
# 	Validation Error (R^2): 0.131202500443
# Leaf: 10
# 	Training Error (MSE): 950.811204014
# 	Validation Error (MSE): 1753.58338593
# 	Training Error (R^2): 0.430109010454
# 	Validation Error (R^2): 0.0857665135381
# Leaf: 15
# 	Training Error (MSE): 1106.36470468
# 	Validation Error (MSE): 1769.89538035
# 	Training Error (R^2): 0.336874372445
# 	Validation Error (R^2): 0.0772622293105
# Leaf: 20
# 	Training Error (MSE): 1186.1225684
# 	Validation Error (MSE): 1812.85820138
# 	Training Error (R^2): 0.289069626677
# 	Validation Error (R^2): 0.054863494254
# Leaf: 30
# 	Training Error (MSE): 1287.38323107
# 	Validation Error (MSE): 1799.41588781
# 	Training Error (R^2): 0.228376674165
# 	Validation Error (R^2): 0.0618716658118
# Leaf: 40
# 	Training Error (MSE): 1337.83280251
# 	Validation Error (MSE): 1808.32888058
# 	Training Error (R^2): 0.198138540594
# 	Validation Error (R^2): 0.057224862857
# Leaf: 50
# 	Training Error (MSE): 1388.99001573
# 	Validation Error (MSE): 1784.60703179
# 	Training Error (R^2): 0.167476265326
# 	Validation Error (R^2): 0.0695922864394
# Leaf: 70
# 	Training Error (MSE): 1445.93948344
# 	Validation Error (MSE): 1797.95934823
# 	Training Error (R^2): 0.133342266517
# 	Validation Error (R^2): 0.0626310350336
# Leaf: 100
# 	Training Error (MSE): 1487.41182815
# 	Validation Error (MSE): 1825.54512899
# 	Training Error (R^2): 0.108484844277
# 	Validation Error (R^2): 0.0482491443736
# Leaf: 200
# 	Training Error (MSE): 1546.49094939
# 	Validation Error (MSE): 1862.66792614
# 	Training Error (R^2): 0.0730743876894
# 	Validation Error (R^2): 0.0288951150537
# Leaf: 500
# 	Training Error (MSE): 1592.33182343
# 	Validation Error (MSE): 1838.93589098
# 	Training Error (R^2): 0.0455985849643
# 	Validation Error (R^2): 0.0412678493181
# Leaf: 1000
# 	Training Error (MSE): 1635.89511524
# 	Validation Error (MSE): 1896.77018398
# 	Training Error (R^2): 0.0194879045559
# 	Validation Error (R^2): 0.0111158487061
# Leaf: 2000
# 	Training Error (MSE): 1668.40890882
# 	Validation Error (MSE): 1918.21158577
# 	Training Error (R^2): 0.0
# 	Validation Error (R^2): -6.26602076641e-05
# Leaf: 3000
# 	Training Error (MSE): 1668.40890882
# 	Validation Error (MSE): 1918.21158577
# 	Training Error (R^2): 0.0
# 	Validation Error (R^2): -6.26602076641e-05
# Leaf: 4000
# 	Training Error (MSE): 1668.40890882
# 	Validation Error (MSE): 1918.21158577
# 	Training Error (R^2): 0.0
# 	Validation Error (R^2): -6.26602076641e-05
# Leaf: 5000
# 	Training Error (MSE): 1668.40890882
# 	Validation Error (MSE): 1918.21158577
# 	Training Error (R^2): 0.0
# 	Validation Error (R^2): -6.26602076641e-05
# Leaf: 1000
# 	Training Error (MSE): 1635.89511524
# 	Validation Error (MSE): 1896.77018398
# 	Training Error (R^2): 0.0194879045559
# 	Validation Error (R^2): 0.0111158487061

# %% [markdown]
# ### K-Fold Cross Validation Error (with shuffling)

# %%
from sklearn.cross_validation import KFold
from sklearn.tree import DecisionTreeRegressor

MSE_stats = pd.DataFrame()
R2_stats = pd.DataFrame()
  
leaves = [1, 2, 3, 5, 7, 10, 15, 20, 30, 40, 50, 70, 100, 200, 500, 1000, 2000, 3000, 4000, 5000, 1000]

train_set = np.copy(train)

for j in range(0, 10):
    
    MSE_list = []
    R2_list = []
    
    kf=KFold(len(train), n_folds=3, shuffle=True) 
    
    for t, t2 in kf:
        x_train = [train_set[ii] for ii in t]
        y_train = [y[ii] for ii in t]
        x_test = [train_set[ii] for ii in t2]
        y_test = [y[ii] for ii in t2]

    for i in leaves:
        DT_model = DecisionTreeRegressor(min_samples_leaf=i)
        DT_model.fit(x_train, y_train)
        preds = DT_model.predict(x_test)
        MSE = mse(y_test, preds)
        MSE_list.append(MSE)
        
        R_squared = DT_model.score(x_test, y_test)
        R2_list.append(R_squared)
    
    MSE_stats[j] = MSE_list
    R2_stats[j] = R2_list
    
kfold_mean_MSE = {}
kfold_mean_R2 = {}

for i in range(len(leaves)):
    print "Leaf:", leaves[i]
    
    kfold_mean_MSE[i] = MSE_stats.loc[i].mean()
    print "\tMSE:", kfold_mean_MSE[i]
    
    kfold_mean_R2[i] = R2_stats.loc[i].mean()
    print "\tR2 value:", kfold_mean_R2[i]
# Out:
# Leaf: 1
# 	MSE: 4457.73170434
# 	R2 value: -1.15013267045
# Leaf: 2
# 	MSE: 3552.03106801
# 	R2 value: -0.70680291506
# Leaf: 3
# 	MSE: 3183.48669595
# 	R2 value: -0.527160097296
# Leaf: 5
# 	MSE: 2762.58468328
# 	R2 value: -0.322992696208
# Leaf: 7
# 	MSE: 2604.85270584
# 	R2 value: -0.243497303655
# Leaf: 10
# 	MSE: 2430.70370064
# 	R2 value: -0.159197072014
# Leaf: 15
# 	MSE: 2324.86852577
# 	R2 value: -0.108391215881
# Leaf: 20
# 	MSE: 2251.0317816
# 	R2 value: -0.0726518059942
# Leaf: 30
# 	MSE: 2179.65142293
# 	R2 value: -0.0373224284222
# Leaf: 40
# 	MSE: 2137.63586064
# 	R2 value: -0.0168917663332
# Leaf: 50
# 	MSE: 2112.30907729
# 	R2 value: -0.00469729130063
# Leaf: 70
# 	MSE: 2082.73338521
# 	R2 value: 0.00956657187993
# Leaf: 100
# 	MSE: 2071.15356178
# 	R2 value: 0.0155099708486
# Leaf: 200
# 	MSE: 2063.66986723
# 	R2 value: 0.0187645951451
# Leaf: 500
# 	MSE: 2057.961408
# 	R2 value: 0.0218079953227
# Leaf: 1000
# 	MSE: 2069.39332775
# 	R2 value: 0.0160524139057
# Leaf: 2000
# 	MSE: 2103.85766543
# 	R2 value: -0.000437754489773
# Leaf: 3000
# 	MSE: 2103.85766543
# 	R2 value: -0.000437754489773
# Leaf: 4000
# 	MSE: 2103.85766543
# 	R2 value: -0.000437754489773
# Leaf: 5000
# 	MSE: 2103.85766543
# 	R2 value: -0.000437754489773
# Leaf: 1000
# 	MSE: 2069.39332775
# 	R2 value: 0.0160524139057

# %%
from sklearn.tree import DecisionTreeRegressor

DT_model = DecisionTreeRegressor(min_samples_leaf=2)
DT_model.fit(x_train, y_train)

fi = DT_model.feature_importances_
#x_train=train_df.drop('churndep', axis=1)
feat_names = np.array( train.columns.values)

# Plotting Feature_Names on X-Axis and Feature_importances on Y-Axis
plt.figure(figsize=(12, 8))
plt.bar(range(len(feat_names)), fi)
plt.xticks(range(len(feat_names)), feat_names, rotation=50)
plt.xlabel('Feature Name')
plt.ylabel('Feature Importance')
plt.title('Feature Importance Ranking')
plt.show()

# %%
DT_model = DecisionTreeRegressor(min_samples_leaf=20)
DT_model.fit(x_train, y_train)

fi = DT_model.feature_importances_
#x_train=train_df.drop('churndep', axis=1)
feat_names = np.array( train.columns.values)

# Plotting Feature_Names on X-Axis and Feature_importances on Y-Axis
plt.figure(figsize=(12, 8))
plt.bar(range(len(feat_names)), fi)
plt.xticks(range(len(feat_names)), feat_names, rotation=50)
plt.xlabel('Feature Name')
plt.ylabel('Feature Importance')
plt.title('Feature Importance Ranking')
plt.show()

# %%
DT_model = DecisionTreeRegressor(min_samples_leaf=500)
DT_model.fit(x_train, y_train)

fi = DT_model.feature_importances_
#x_train=train_df.drop('churndep', axis=1)
feat_names = np.array( train.columns.values)

# Plotting Feature_Names on X-Axis and Feature_importances on Y-Axis
plt.figure(figsize=(12, 8))
plt.bar(range(len(feat_names)), fi)
plt.xticks(range(len(feat_names)), feat_names, rotation=50)
plt.xlabel('Feature Name')
plt.ylabel('Feature Importance')
plt.title('Feature Importance Ranking')
plt.show()

# %% [markdown]
# ### Less Features

# %%
from sklearn.cross_validation import KFold
from sklearn.tree import DecisionTreeRegressor

MSE_stats = pd.DataFrame()
R2_stats = pd.DataFrame()
  
leaves = [1, 2, 3, 5, 7, 10, 15, 20, 30, 40, 50, 70, 100, 200, 500, 1000, 2000, 3000, 4000, 5000, 1000]

train_set = np.array(train.drop(['UID', 'AIRLINE_ID', 'DAY_OF_WEEK', 'DISTANCE_GROUP', 'month'], axis = 1))

for j in range(0, 10):
    
    MSE_list = []
    R2_list = []
    
    kf=KFold(len(train), n_folds=3, shuffle=True) 
    
    for t, t2 in kf:
        x_train = [train_set[ii] for ii in t]
        y_train = [y[ii] for ii in t]
        x_test = [train_set[ii] for ii in t2]
        y_test = [y[ii] for ii in t2]

    for i in leaves:
        DT_model = DecisionTreeRegressor(min_samples_leaf=i)
        DT_model.fit(x_train, y_train)
        preds = DT_model.predict(x_test)
        MSE = mse(y_test, preds)
        MSE_list.append(MSE)
        
        R_squared = DT_model.score(x_test, y_test)
        R2_list.append(R_squared)
    
    MSE_stats[j] = MSE_list
    R2_stats[j] = R2_list
    
kfold_mean_MSE = {}
kfold_mean_R2 = {}

for i in range(len(leaves)):
    print "Leaf:", leaves[i]
    
    kfold_mean_MSE[i] = MSE_stats.loc[i].mean()
    print "\tMSE:", kfold_mean_MSE[i]
    
    kfold_mean_R2[i] = R2_stats.loc[i].mean()
    print "\tR2 value:", kfold_mean_R2[i]
# Out:
# Leaf: 1
# 	MSE: 4623.14618204
# 	R2 value: -1.42223505558
# Leaf: 2
# 	MSE: 3550.08811003
# 	R2 value: -0.840027080246
# Leaf: 3
# 	MSE: 3059.50054851
# 	R2 value: -0.58289429341
# Leaf: 5
# 	MSE: 2588.02625905
# 	R2 value: -0.334497485747
# Leaf: 7
# 	MSE: 2426.81889502
# 	R2 value: -0.247306204219
# Leaf: 10
# 	MSE: 2254.02193363
# 	R2 value: -0.155583905641
# Leaf: 15
# 	MSE: 2135.73663829
# 	R2 value: -0.0950005956034
# Leaf: 20
# 	MSE: 2070.60833839
# 	R2 value: -0.0609196990702
# Leaf: 30
# 	MSE: 2020.80845729
# 	R2 value: -0.0337624869366
# Leaf: 40
# 	MSE: 1978.03521648
# 	R2 value: -0.0123127355934
# Leaf: 50
# 	MSE: 1970.58976198
# 	R2 value: -0.00818040572159
# Leaf: 70
# 	MSE: 1944.71206793
# 	R2 value: 0.00467853725192
# Leaf: 100
# 	MSE: 1924.03012946
# 	R2 value: 0.0157367359277
# Leaf: 200
# 	MSE: 1905.96162587
# 	R2 value: 0.0258464797059
# Leaf: 500
# 	MSE: 1908.83090408
# 	R2 value: 0.0242603033723
# Leaf: 1000
# 	MSE: 1920.94901371
# 	R2 value: 0.017751207161
# Leaf: 2000
# 	MSE: 1956.87891392
# 	R2 value: -0.000826313823085
# Leaf: 3000
# 	MSE: 1956.87891392
# 	R2 value: -0.000826313823085
# Leaf: 4000
# 	MSE: 1956.87891392
# 	R2 value: -0.000826313823085
# Leaf: 5000
# 	MSE: 1956.87891392
# 	R2 value: -0.000826313823085
# Leaf: 1000
# 	MSE: 1920.94901371
# 	R2 value: 0.017751207161

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

LR_model = LinearRegression()
LR_model.fit(x_train, y_train)
preds = LR_model.predict(x_test)
print "MSE:", mse(y_test, preds)
print "MAE:", mae(y_test, preds)
# Out:
# MSE: 1600.97313818
# MAE: 20.9775644971

# %% [markdown]
# ### Less features

# %%
from sklearn.linear_model import LinearRegression

LR_model = LinearRegression()
LR_model.fit(x_train, y_train)
preds = LR_model.predict(x_test)
print i, "MSE:", mse(y_test, preds)
R_squared = LR_model.score(x_test, y_test)
#R2.append([R_squared, i])
print i, "R^2 value:", R_squared
# Out:
# 100000 MSE: 1647.95193178
# 100000 R^2 value: 0.0761479466118

# %% [markdown]
# # K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsRegressor

KNN_model = KNeighborsRegressor()
KNN_model.fit(x_train, y_train)
preds = KNN_model.predict(x_test)
print "MSE:", mse(y_test, preds)
print "MAE:", mae(y_test, preds)
# Out:
# MSE: 1952.48855539
# MAE: 24.6099030117

# %% [markdown]
# ### Less Features

# %%
from sklearn.neighbors import KNeighborsRegressor

neighbors = [1, 2, 3, 5, 8, 10, 15, 20, 30, 50, 70, 100, 200, 300, 500, 700]

for i in neighbors:    
    KNN_model = KNeighborsRegressor(n_neighbors=i)
    KNN_model.fit(x_train, y_train)
    preds = KNN_model.predict(x_test)
    print i, "MSE:", mse(y_test, preds)
    R_squared = KNN_model.score(x_test, y_test)
    #R2.append([R_squared, i])
    print i, "R^2 value:", R_squared
# Out:
# 1 MSE: 2439.79913221
# 1 R^2 value: -0.367766495294
# 2 MSE: 2256.54134763
# 2 R^2 value: -0.265031046934
# 3 MSE: 2172.93914129
# 3 R^2 value: -0.218163132581
# 5 MSE: 2037.12866769
# 5 R^2 value: -0.142026940448
# 8 MSE: 1916.9735356
# 8 R^2 value: -0.0746672296708
# 10 MSE: 1895.35255232
# 10 R^2 value: -0.062546372614
# 15 MSE: 1853.58756962
# 15 R^2 value: -0.0391326647966
# 20 MSE: 1835.73521184
# 20 R^2 value: -0.0291245225238
# 30 MSE: 1799.73593415
# 30 R^2 value: -0.00894310462234
# 50 MSE: 1788.51057295
# 50 R^2 value: -0.00265009764867
# 70 MSE: 1779.68174001
# 70 R^2 value: 0.00229940074504
# 100 MSE: 1775.01229117
# 100 R^2 value: 0.00491712266635
# 200 MSE: 1768.64964993
# 200 R^2 value: 0.00848405872825
# 300 MSE: 1772.86750856
# 300 R^2 value: 0.00611950107013
# 500 MSE: 1777.74024251
# 500 R^2 value: 0.00338781626122
# 700 MSE: 1782.55798141
# 700 R^2 value: 0.000686962011645

# %% [markdown]
# # Support Vector Machines

# %%
from sklearn.svm import SVR as SVM

SVM_model = SVM()
SVM_model.fit(x_train, y_train)
preds = SVM_model.predict(x_test)
print "MSE:", mse(y_test, preds)
print "MAE:", mae(y_test, preds)
# Out:
# MSE: 1902.75495598
# MAE: 19.8121562168

# %% [markdown]
# ### Less features

# %%
from sklearn.svm import SVR as SVM

SVM_model = SVM()
SVM_model.fit(x_train, y_train)
preds = SVM_model.predict(x_test)
print i, "MSE:", mse(y_test, preds)
R_squared = SVM_model.score(x_test, y_test)
#R2.append([R_squared, i])
print i, "R^2 value:", R_squared
# Out:
# 700 MSE: 1877.18701074
# 700 R^2 value: -0.0523626575635

# %% [markdown]
# # Random Forests

# %%
from sklearn.ensemble import RandomForestRegressor

trees = [5, 10, 20, 30, 50, 70, 80, 100, 200, 500, 700, 1000, 2000]
for i in trees:
    RF_model = RandomForestRegressor(n_estimators=i)
    RF_model.fit(x_train, y_train)
    preds = RF_model.predict(x_test)
    print i, "MSE:", mse(y_test, preds)
    R_squared = RF_model.score(x_test, y_test)
    #R2.append([R_squared, i])
    print i, "R^2 value:", R_squared
# Out:
# 5 MSE: 1776.22795304
# 5 R^2 value: 0.00423561509832
# 10 MSE: 1542.91437979
# 10 R^2 value: 0.135032648419
# 20 MSE: 1543.12219819
# 20 R^2 value: 0.134916144136
# 30 MSE: 1494.31322897
# 30 R^2 value: 0.162278754395
# 50 MSE: 1488.98705391
# 50 R^2 value: 0.165264641105
# 70 MSE: 1474.13078497
# 70 R^2 value: 0.173593157427
# 80 MSE: 1464.22762231
# 80 R^2 value: 0.179144931711
# 100 MSE: 1468.3396734
# 100 R^2 value: 0.176839690416
# 200 MSE: 1477.11727087
# 200 R^2 value: 0.171918914948
# 500 MSE: 1458.83158518
# 500 R^2 value: 0.182169983528
# 700 MSE: 1461.13143877
# 700 R^2 value: 0.180880671369
# 1000 MSE: 1457.59070484
# 1000 R^2 value: 0.182865628725
# 2000 MSE: 1461.11152666
# 2000 R^2 value: 0.18089183422

# %% [markdown]
# ### Less Features

# %%
from sklearn.ensemble import RandomForestRegressor

trees = [5, 10, 20, 30, 50, 70, 80, 100, 200, 500, 700, 1000, 2000]
for i in trees:
    RF_model = RandomForestRegressor(n_estimators=i)
    RF_model.fit(x_train, y_train)
    
    preds_train = RF_model.predict(x_train)
    print i, "Training MSE:", mse(y_train, preds_train)    
    
    preds_test = RF_model.predict(x_test)
    print i, "Testing MSE:", mse(y_test, preds_test)
    R_squared = RF_model.score(x_test, y_test)
    #R2.append([R_squared, i])
    print i, "R^2 value:", R_squared
# Out:
# 5 Training MSE: 587.149898167
# 5 Testing MSE: 2450.64629579
# 5 R^2 value: -0.210993789801
# 10 Training MSE: 448.519071865
# 10 Testing MSE: 2311.19717775
# 10 R^2 value: -0.142084614195
# 20 Training MSE: 362.384228251
# 20 Testing MSE: 2134.08387551
# 20 R^2 value: -0.0545635755728
# 30 Training MSE: 338.353672777
# 30 Testing MSE: 2038.95371702
# 30 R^2 value: -0.00755473902654
# 50 Training MSE: 324.591044748
# 50 Testing MSE: 2063.62005617
# 50 R^2 value: -0.0197436801978
# 70 Training MSE: 296.624484214
# 70 Testing MSE: 2082.69546908
# 70 R^2 value: -0.0291698493724
# 80 Training MSE: 299.93654868
# 80 Testing MSE: 2094.91752968
# 80 R^2 value: -0.0352094151426
# 100 Training MSE: 317.129987315
# 100 Testing MSE: 2072.98000142
# 100 R^2 value: -0.0243689235842
# 200 Training MSE: 306.531465697
# 200 Testing MSE: 2032.651494
# 200 R^2 value: -0.00444047771582
# 500 Training MSE: 287.922813978
# 500 Testing MSE: 2040.90766979
# 500 R^2 value: -0.00852029030886
# 700 Training MSE: 286.124219336
# 700 Testing MSE: 2028.46338733
# 700 R^2 value: -0.00237091297468
# 1000 Training MSE: 294.321186286
# 1000 Testing MSE: 2016.84715308
# 1000 R^2 value: 0.00336928199451
# 2000 Training MSE: 289.466111595
# 2000 Testing MSE: 2025.44810274
# 2000 R^2 value: -0.000880901579289

# %%
from sklearn.cross_validation import KFold
from sklearn.ensemble import RandomForestRegressor

MSE_stats = pd.DataFrame()
R2_stats = pd.DataFrame()
  
trees = [5, 10, 20, 30, 50, 70, 80, 100, 200, 500, 700, 1000, 2000]

train_set = np.copy(train)

for j in range(0, 10):
    
    MSE_list = []
    R2_list = []
    
    kf=KFold(len(train), n_folds=3, shuffle=True) 
    
    for t, t2 in kf:
        x_train = [train_set[ii] for ii in t]
        y_train = [y[ii] for ii in t]
        x_test = [train_set[ii] for ii in t2]
        y_test = [y[ii] for ii in t2]

    for i in trees:
        RF_model = RandomForestRegressor(n_estimators=i)
        RF_model.fit(x_train, y_train)
        preds = RF_model.predict(x_test)
        MSE = mse(y_test, preds)
        MSE_list.append(MSE)
        
        R_squared = RF_model.score(x_test, y_test)
        R2_list.append(R_squared)
    
    MSE_stats[j] = MSE_list
    R2_stats[j] = R2_list
    
kfold_mean_MSE = {}
kfold_mean_R2 = {}

for i in range(len(leaves)):
    print "Leaf:", leaves[i]
    
    kfold_mean_MSE[i] = MSE_stats.loc[i].mean()
    print "\tMSE:", kfold_mean_MSE[i]
    
    kfold_mean_R2[i] = R2_stats.loc[i].mean()
    print "\tR2 value:", kfold_mean_R2[i]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-243-6454ae886bff> in <module>()
#      24     for i in trees:
#      25         RF_model = RandomForestRegressor(n_estimators=i)
# ---> 26         RF_model.fit(x_train, y_train)
#      27         preds = RF_model.predict(x_test)
#      28         MSE = mse(y_test, preds)
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in fit(self, X, y, sample_weight)
#     325                     t, self, X, y, sample_weight, i, len(trees),
#     326                     verbose=self.verbose, class_weight=self.class_weight)
# --> 327                 for i, t in enumerate(trees))
#     328
#     329             # Collect newly grown trees
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     118             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     119
# --> 120         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     121     else:
#     122         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1122             sample_weight=sample_weight,
#    1123             check_input=check_input,
# -> 1124             X_idx_sorted=X_idx_sorted)
#    1125         return self
#    1126
#
# /Users/harshitsrivastava/anaconda2/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:
